# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading the datasets

# %%
df=pd.read_csv("netflix1.csv")
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %% [markdown]
# Data Cleaning

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df['country'].value_counts().get("Not Given", 0)
# Out:
# 287

# %%
# this creates the separate dataframe where the all the Not Given values in Column gets droped
df = df[df['country'] != "Not Given"]

# %%
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df['country'].unique()
# Out:
# array(['United States', 'France', 'Brazil', 'United Kingdom', 'India',
#        'Germany', 'Pakistan', 'China', 'South Africa', 'Japan', 'Nigeria',
#        'Spain', 'Philippines', 'Australia', 'Argentina', 'Canada',
#        'Hong Kong', 'Italy', 'New Zealand', 'Egypt', 'Colombia', 'Mexico',
#        'Belgium', 'Switzerland', 'Taiwan', 'Bulgaria', 'Poland',
#        'South Korea', 'Saudi Arabia', 'Thailand', 'Indonesia', 'Kuwait',
#        'Malaysia', 'Vietnam', 'Lebanon', 'Romania', 'Syria',
#        'United Arab Emirates', 'Sweden', 'Mauritius', 'Austria', 'Turkey',
#        'Czech Republic', 'Cameroon', 'Netherlands', 'Ireland', 'Russia',
#        'Kenya', 'Chile', 'Uruguay', 'Bangladesh', 'Portugal', 'Hungary',
#        'Norway', 'Singapore', 'Iceland', 'Serbia', 'Namibia', 'Peru',
#        'Mozambique', 'Ghana', 'Zimbabwe', 'Israel', 'Finland', 'Denmark',
#        'Paraguay', 'Cambodia', 'Georgia', 'Soviet Union', 'Greece',
# ...

# %%
# if we need the number of unique data present in country column use nunique()
df['country'].nunique()
# Out:
# 85

# %%
df['director'].value_counts().get("Not Given", 0)
# Out:
# 2588

# %%
df = df[df['director'] != "Not Given"]

# %%
df
# Out:
#      show_id     type                              title  \
# 0         s1    Movie               Dick Johnson Is Dead
# 1         s3  TV Show                          Ganglands
# 2         s6  TV Show                      Midnight Mass
# 3        s14    Movie   Confessions of an Invisible Girl
# 4         s8    Movie                            Sankofa
# ...      ...      ...                                ...
# 6565   s3351    Movie         True: Grabbleapple Harvest
# 6566   s3509    Movie             True: Tricky Treat Day
# 6567   s3554  TV Show       True and the Rainbow Kingdom
# 6568   s4241    Movie  Sam Kinison: The Scream Continues
# 6569   s1315  TV Show                   Chappelle's Show
#
#                           director        country  date_added  release_year  \
# 0                  Kirsten Johnson  United States   9/25/2021          2020
# 1                  Julien Leclercq         France   9/24/2021          2021
# ...

# %%
df['date_added'].value_counts().get("Not Given", 0)
# Out:
# 0

# %%
df['release_year'].value_counts().get("Not Given", 0)
# Out:
# 0

# %%
df['rating'].value_counts().get("Not Given", 0)
# Out:
# 0

# %%
df['duration'].value_counts().get("Not Given", 0)
# Out:
# 0

# %%
df['listed_in'].value_counts().get("Not Given", 0)
# Out:
# 0

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'TV-PG', 'TV-14', 'TV-Y7', 'TV-Y', 'TV-G', 'PG',
#        'R', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df['rating'].nunique()
# Out:
# 14

# %%
df['release_year'].unique()
# Out:
# array([2020, 2021, 1993, 2019, 2013, 2014, 2018, 1998, 2010, 1997, 2017,
#        1975, 1978, 1983, 1987, 2012, 2001, 2002, 2003, 2004, 2011, 2008,
#        2009, 2007, 2005, 2006, 1994, 2015, 1982, 2016, 1989, 1990, 1991,
#        1999, 1986, 1996, 1984, 1980, 1961, 2000, 1995, 1985, 1992, 1976,
#        1959, 1988, 1972, 1981, 1964, 1954, 1979, 1958, 1956, 1963, 1970,
#        1973, 1960, 1974, 1966, 1971, 1962, 1969, 1977, 1967, 1968, 1965,
#        1945, 1946, 1942, 1955, 1944, 1947, 1943], dtype=int64)

# %% [markdown]
# Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. **PG-13 (Parents Strongly Cautioned)**: Some material may be inappropriate for children under 13. Parents are urged to be cautious about the content and consider whether it is suitable for their children.
#
# 2. **TV-MA (Mature Audiences)**: This program is specifically designed to be viewed by adults and is not suitable for children under 17. It may contain explicit content, such as strong language, sexual content, or graphic violence.
#
# 3. **TV-PG (Parental Guidance Suggested)**: Some material may not be suitable for children. Parents are urged to provide "parental guidance," and the content may contain infrequent mild language, some violence, or suggestive dialogue.
#
# 4. **TV-14 (Parents Strongly Cautioned - Ages 14 and above)**: This program may be unsuitable for children under 14 years of age. Parents are strongly cautioned, as it may contain intense violence, sexual content, or strong language.
#
# 5. **TV-Y7 (Directed to Older Children - Ages 7 and above)**: This program is designed for children aged 7 and above. It may be more intense than content designated as TV-Y and may contain fantasy violence or comedic violence.
#
# 6. **TV-Y (All Children)**: This program is suitable for all children. It contains little or no violence, no strong language, and little or no sexual content.
#
# 7. **TV-G (General Audience)**: All ages are admitted. It is specifically designed for children and may be suitable for all audiences.
#
# 8. **PG (Parental Guidance Suggested)**: Some material may not be suitable for children. Parents are urged to provide "parental guidance." This may include some mild language, thematic elements, or brief violence.
#
# 9. **R (Restricted)**: Restricted to viewers over the age of 17 or 18. Parents are strongly urged to learn more about the movie before taking their children to see it. It may contain adult themes, adult activity, hard language, intense or persistent violence, sexually-oriented nudity, drug abuse, or other elements.
#
# 10. **G (General Audience)**: All ages are admitted. It is specifically designed for children and may be suitable for all audiences.
#
# 11. **NC-17 (Adults Only)**: No one 17 and under admitted. It is similar to an R rating but indicates a stricter stance on age restrictions.
#
# 12. **NR (Not Rated)**: This film has not been submitted for a rating or is an uncut version of a film that was submitted.
#
# 13. **TV-Y7-FV (Directed to Older Children - Fantasy Violence)**: This program is designed for children aged 7 and above and may contain fantasy violence.
#
# 14. **UR (Unrated)**: This film has not been submitted for a rating or is an uncut version of a film that was submitted.
#
# These ratings are provided by organizations like the Motion Picture Association (MPA) for movies and the TV Parental Guidelines for television shows. They aim to assist viewers in making informed decisions about the content they consume based on their own preferences and the age appropriateness for their audience.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='rating', data=df)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')  
plt.show()

# %%
release_year_counts = df['release_year'].value_counts()
print(release_year_counts)
# Out:
# release_year
# 2017    744
# 2018    730
# 2016    645
# 2019    598
# 2020    503
#        ...
# 1966      1
# 1961      1
# 1963      1
# 1959      1
# 1947      1
# Name: count, Length: 73, dtype: int64

# %%
plt.figure(figsize=(15, 6))


sns.countplot(x='release_year', data=df, palette='viridis',hue='release_year', legend=False) 

# Customize the plot
plt.title('Distribution of Movies across Years')
plt.xlabel('Year')
plt.ylabel('Count')


plt.xticks(rotation=45, ha='right')
plt.show()

# %%
top_categories = df['listed_in'].value_counts()
print(top_categories)
# Out:
# listed_in
# Dramas, International Movies                             346
# Documentaries                                            328
# Stand-Up Comedy                                          296
# Comedies, Dramas, International Movies                   262
# Dramas, Independent Movies, International Movies         245
#                                                         ...
# Comedies, LGBTQ Movies, Thrillers                          1
# Comedies, Documentaries                                    1
# British TV Shows, Romantic TV Shows, TV Dramas             1
# Horror Movies, International Movies, Sci-Fi & Fantasy      1
# Kids' TV, TV Action & Adventure                            1
# Name: count, Length: 349, dtype: int64

# %%
top_directors = df['director'].value_counts()
print(top_directors)
# Out:
# director
# Rajiv Chilaka             20
# Alastair Fothergill       18
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
#                           ..
# Wagner de Assis            1
# White Trash Tyler          1
# Yeung Yat-Tak              1
# Rai Yuvraj Bains           1
# Mozez Singh                1
# Name: count, Length: 4286, dtype: int64

# %%
country_distribution = df['country'].value_counts()
print(country_distribution)
# Out:
# country
# United States     2401
# India              975
# United Kingdom     406
# Canada             189
# France             156
#                   ...
# Zimbabwe             1
# Mozambique           1
# Namibia              1
# Mauritius            1
# Croatia              1
# Name: count, Length: 78, dtype: int64

# %%
plt.figure(figsize=(15, 6))


sns.countplot(x='country', data=df, palette='viridis',hue='country', legend=False) 

# Customize the plot
plt.title('Distribution of Movies of different countries')
plt.xlabel('Country')
plt.ylabel('Count')


plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Monthly addition of content
df = df.copy()

# Convert 'date_added' to datetime
df['date_added'] = pd.to_datetime(df['date_added'])

# Extract the month and create a new column
df['month_added'] = df['date_added'].dt.month

# Count the occurrences of each month
monthly_addition = df['month_added'].value_counts().sort_index()

# Print the result
print(monthly_addition)
# Out:
# month_added
# 1     528
# 2     380
# 3     520
# 4     535
# 5     422
# 6     466
# 7     531
# 8     492
# 9     485
# 10    532
# 11    490
# 12    534
# Name: count, dtype: int64
